# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.1

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df=pd.read_csv('C:/Users/Kavitha/Desktop/anudp file/python/food price.csv')
# Out:
# C:\Users\Kavitha\AppData\Local\Temp\ipykernel_6772\3156419759.py:1: DtypeWarning: Columns (4,5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('C:/Users/Kavitha/Desktop/anudp file/python/food price.csv')

# %%
df.head()
# Out:
#          date      admin1      admin2            market   latitude  longitude  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat   #geo+lon
# 1  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 2  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 3  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 4  1994-01-15     Gujarat   Ahmadabad         Ahmedabad  23.033333  72.616667
#
#              category      commodity        unit         priceflag  \
# 0          #item+type     #item+name  #item+unit  #item+price+flag
# 1  cereals and tubers           Rice          KG            actual
# 2  miscellaneous food          Sugar          KG            actual
# 3        oil and fats  Oil (mustard)          KG            actual
# 4  cereals and tubers           Rice          KG            actual
#
#           pricetype   currency   price    usdprice
# ...

# %%
df.tail()
# Out:
#               date     admin1  admin2      market   latitude  longitude  \
# 168491  2024-01-15  Rajasthan  Jaipur  North Zone  26.938848  75.800056
# 168492  2024-01-15  Rajasthan  Jaipur  North Zone  26.938848  75.800056
# 168493  2024-01-15  Rajasthan  Jaipur  North Zone  26.938848  75.800056
# 168494  2024-01-15  Rajasthan  Jaipur  North Zone  26.938848  75.800056
# 168495  2024-01-15  Rajasthan  Jaipur  North Zone  26.938848  75.800056
#
#                      category        commodity unit priceflag pricetype  \
# 168491           oil and fats    Oil (soybean)   KG    actual    Retail
# 168492           oil and fats  Oil (sunflower)   KG    actual    Retail
# 168493        pulses and nuts          Lentils   KG    actual    Retail
# 168494        pulses and nuts  Lentils (moong)   KG    actual    Retail
# 168495  vegetables and fruits           Onions   KG    actual    Retail
#
#        currency   price usdprice
# 168491      INR  128.47   1.5502
# ...

# %%
df.head(50)
# Out:
#           date            admin1            admin2            market  \
# 0        #date        #adm1+name        #adm2+name  #loc+market+name
# 1   1994-01-15             Delhi             Delhi             Delhi
# 2   1994-01-15             Delhi             Delhi             Delhi
# 3   1994-01-15             Delhi             Delhi             Delhi
# 4   1994-01-15           Gujarat         Ahmadabad         Ahmedabad
# 5   1994-01-15           Gujarat         Ahmadabad         Ahmedabad
# 6   1994-01-15           Gujarat         Ahmadabad         Ahmedabad
# 7   1994-01-15           Gujarat         Ahmadabad         Ahmedabad
# 8   1994-01-15  Himachal Pradesh            Shimla            Shimla
# 9   1994-01-15  Himachal Pradesh            Shimla            Shimla
# 10  1994-01-15  Himachal Pradesh            Shimla            Shimla
# 11  1994-01-15         Karnataka   Bangalore Urban         Bengaluru
# 12  1994-01-15         Karnataka   Bangalore Urban         Bengaluru
# ...

# %%
df.describe()
# Out:
#               date         admin1       admin2  market latitude  longitude  \
# count       168496         167867       167867  168496   167867     167867
# unique         362             32          164     171      225        221
# top     2022-07-15  Uttar Pradesh  Mumbai city  Mumbai   18.975  72.825833
# freq          2580          13211         3677    3677     2618       2618
#
#             category commodity    unit priceflag pricetype currency     price  \
# count         168496    168496  168496    168496    168496   168496  168496.0
# unique             7        24       4         2         3        2   28893.0
# top     oil and fats      Rice      KG    actual    Retail      INR      40.0
# freq           41728     12337  157961    168495    166602   168495    1454.0
#
#            usdprice
# count   168496.0000
# unique   44310.0000
# top          0.2729
# freq        78.0000

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'priceflag', 'pricetype', 'currency',
#        'price', 'usdprice'],
#       dtype='object')

# %%
df.shape
# Out:
# (168496, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168496 entries, 0 to 168495
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       168496 non-null  object
#  1   admin1     167867 non-null  object
#  2   admin2     167867 non-null  object
#  3   market     168496 non-null  object
#  4   latitude   167867 non-null  object
#  5   longitude  167867 non-null  object
#  6   category   168496 non-null  object
#  7   commodity  168496 non-null  object
#  8   unit       168496 non-null  object
#  9   priceflag  168496 non-null  object
#  10  pricetype  168496 non-null  object
#  11  currency   168496 non-null  object
#  12  price      168496 non-null  object
#  13  usdprice   168496 non-null  object
# dtypes: object(14)
# memory usage: 18.0+ MB

# %%
df.count()
# Out:
# date         168496
# admin1       167867
# admin2       167867
# market       168496
# latitude     167867
# longitude    167867
# category     168496
# commodity    168496
# unit         168496
# priceflag    168496
# pricetype    168496
# currency     168496
# price        168496
# usdprice     168496
# dtype: int64

# %%
df['market'].unique()
# Out:
# array(['#loc+market+name', 'Delhi', 'Ahmedabad', 'Shimla', 'Bengaluru',
#        'Bhopal', 'Mumbai', 'Bhubaneshwar', 'Hyderabad', 'Agartala',
#        'Kolkata', 'Shillong', 'Jaipur', 'Chennai', 'Guwahati',
#        'Tiruvanantapuram', 'Lucknow', 'Aizawl', 'Patna', 'Chandigarh',
#        'Ranchi', 'Raipur', 'Kohima', 'Amritsar', 'Ludhiana', 'Dehradun',
#        'Vijaywada', 'Rajkot', 'Dindigul', 'Kanpur', 'Bhagalpur', 'Hisar',
#        'Karnal', 'Mandi', 'Dharwad', 'Nagpur', 'Cuttack', 'Sambalpur',
#        'Thiruchirapalli', 'Agra', 'Varanasi', 'Siliguri', 'Indore',
#        'Dimapur', 'Bathinda', 'Jodhpur', 'Ernakulam', 'Kota',
#        'Port Blair', 'Puducherry', 'Panaji', 'Gurgaon', 'Panchkula',
#        'Kozhikode', 'T.Puram', 'Gwalior', 'Jabalpur', 'Rourkela',
#        'National Average', 'Mayabunder', 'Tirupathi', 'Kurnool',
#        'Visakhapatnam', 'Darbhanga', 'Bihar_Gaya', 'Muzzafarpur',
#        'Purnia', 'Jagdalpur', 'Bilaspur', 'Durg', 'Ambikapur', 'Bhuj',
# ...

# %%
df['commodity'].nunique()
# Out:
# 24

# %%
df = pd.DataFrame({'price': [283,172,176,173,110,100,110,31,39,26,35,66,42,24,91,103,29]})
median_value=df['price'].median()
print("Median:", median_value)
# Out:
# Median: 91.0

# %%
pip install adapt
# Out:
# ...
#
#   Using cached adapt-0.4.4.tar.gz (100 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached tensorflow-2.16.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached scikit_learn-1.4.1.post1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached cvxopt-1.3.2-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached scikeras-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached packaging-21.3-py3-none-any.whl.metadata (15 kB)
# ...

# %%
np.random.seed(0)
Xs = np.linspace(0, 1, 200)
ys = (1 - Xs**2) * np.sin(2 * 2 * np.pi * Xs) - Xs + 0.1 * np.random.randn(len(Xs))

Xt = Xs[:100]
yt = (1 - Xt**2) * np.sin(2 * 2 * np.pi * Xt) - Xt - 1.5
gt = (1 - Xs**2) * np.sin(2 * 2 * np.pi * Xs) - Xs - 1.5plt.figure(figsize=(10,6))
plt.plot(Xs, ys, '.', label="commodity", ms=15, alpha=0.9, markeredgecolor="black")
plt.plot(Xt, yt, '.', label="price", ms=15, alpha=0.9, markeredgecolor="black")
plt.plot(Xs, gt, c="black", alpha=0.7, ls="--", label="admin2")
plt.legend(fontsize=14)
plt.xlabel("X", fontsize=16)
plt.ylabel("y = f(X)", fontsize=16)
plt.show()

# %%
import matplotlib.animation as animation
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.layers import Dense, Input, Dropout, Conv2D, MaxPooling2D, Flatten, Reshape, GaussianNoise, BatchNormalization
from tensorflow.keras.constraints import MinMaxNorm
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import clone_model

from adapt.parameter_based import RegularTransferNN

# %%
df = pd.DataFrame({'price': [283,172,176,173,110,100,110,31,39,26,35,66,42,24,91,103,29]})
mean_value=df['price'].mean()
print("Mean:", mean_value)
# Out:
# Mean: 94.70588235294117

# %%
df = pd.DataFrame({'price': [283,172,176,173,110,100,110,31,39,26,35,66,42,24,91,103,29]})
mode_value=df['price'].mode()
print("Mode:", mean_value)
# Out:
# Mode: 0    110
# Name: price, dtype: int64

# %%
plt.figure(figsize=(10,5))
food_market = ['Delhi', 'Ahmedabad', 'Shimla', 'Bengaluru', 'Bhopal', 'Mumbai', 'Bhubaneshwar', 'Hyderabad', 'Agartala', 'Kolkata','Jaipur', 'Chennai','Lucknow', 'Aizawl', 'Patna', 'Chandigarh']
food_price = [128, 172, 176, 173, 110, 100, 31, 39, 26, 35, 66, 2, 24, 91, 103, 29]
plt.plot(food_market, food_price, marker='')
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.title('Food Prices in Different Cities')
plt.show()

# %%
admin1_data = ['Delhi', 'Ahmedabad', 'Shimla', 'Bengaluru', 'Bhopal', 'Mumbai', 'Bhubaneshwar', 'Hyderabad', 'Agartala', 'Kolkata', 'Jaipur', 'Chennai', 'Lucknow', 'Aizawl', 'Patna', 'Chandigarh', 'Delhi', 'Ahmedabad', 'Shimla', 'Bengaluru', 'Bhopal', 'Mumbai', 'Bhubaneshwar', 'Hyderabad', 'Agartala', 'Kolkata', 'Jaipur', 'Chennai', 'Lucknow', 'Aizawl', 'Patna', 'Chandigarh']  # Example data for admin1
commodity_data = ['rice', 'oil', 'wheat', 'mustard', 'sugar', 'tomatoes', 'onion', 'lentils', 'rice', 'oil', 'wheat', 'mustard', 'sugar', 'tomatoes', 'onion', 'lentils']  # Example data for commodity

plt.figure(figsize=(10, 5))  # Adjusted figsize
plt.hist([admin1_data, commodity_data], bins=15, color=['green', 'blue'], edgecolor='violet', label=['admin1', 'commodity'])  # Using example data and added label
plt.title('Hist Chart Example: Admin1 vs Commodity')
plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# plt.figure(figsize=(8, 6))
# market_data = ['vegetables and fruit', 'cereals and pulses', 'oil and fats', 'pulses and nuts', 'milk and dairy']
# category_data = ['Delhi', 'Ahmedabad', 'Buthan', 'Guwathi', 'Kolkata']
#
# plt.scatter(market_data, category_data, color='purple', alpha=0.5)
# plt.title('Scatter plot of Market Data vs Category Data')
# plt.xlabel('Market')
# plt.ylabel('Category')
# plt.grid(True)
# plt.show()
